# %% [markdown]
# Homework 3
# ========
#
# 程序设计，2024年春季
#
# **作业截至日期：2024年5月19日 23:59**
#
# **注:**
# * 将答案写在每个题目下方，__并运行，展示结果__。最后将`*.ipynb`文件打包成zip或者rar文件，命名成`名字-学号.zip`或者`名字-学号.rar`，上传至canvas。做作业过程中，__切记随手保存__。
# * 对于代码，请根据思路适当添加空行和注释，方便理解。
# * 如有参考同学的代码，请在题目代码第一行通过注释标明其学号；若无标明，发现抄袭以0分计。
# * 目前课程覆盖范围足够解答以下题目。如果之前学过Python,允许使用未学过的知识点。

# %% [markdown]
# ### Q1. 根据结果补充代码：函数参数的使用（15pts）
# 编写`print_student()`函数的代码，使得按以下方式调用函数的时候，能得到预期结果。注：该题有多种实现方式，能实现预期效果即可。
#
# 调用：
# ```python
# print_student('Han Meimei', 25)
# print_student('Zhang Dongdong', age=25)
# print_student('Li Weiwei', 25, gender='F', city='shanghai')
# print_student('Li Weiwei', 25, gender='F', city='shanghai', score=15, ID=23, addr='No1. Str.')
# ```
#
# 预期结果:
# ```
# ==info of Han Meimei==
# age:25
# gender:M
# ==info of Zhang Dongdong==
# age:25
# gender:M
# ==info of Li Weiwei==
# age:25
# gender:F
# ==info of Li Weiwei==
# age:25
# gender:F
# score:15
# ID:23
# ```

# %%
# your codes here



            
print_student('Han Meimei', 25)
print_student('Zhang Dongdong', age=25)
print_student('Li Weiwei', 25, gender='F', city='shanghai')
print_student('Li Weiwei', 25, gender='F', city='shanghai', score=15, ID=23, addr='No1. Str.')

# %%
# your codes here
def print_student(name, age, gender='M', **kwargs):
    print(f'==info of {name}==')
    print(f'age:{age}')
    print(f'gender:{gender}')
    for k, v in kwargs.items():
        if type(v) == int:
            print(f'{k}:{v}')
            
print_student('Han Meimei', 25)
print_student('Zhang Dongdong', age=25)
print_student('Li Weiwei', 25, gender='F', city='shanghai')
print_student('Li Weiwei', 25, gender='F', city='shanghai', score=15, ID=23, addr='No1. Str.')
# Out:
# ==info of Han Meimei==
# age:25
# gender:M
# ==info of Zhang Dongdong==
# age:25
# gender:M
# ==info of Li Weiwei==
# age:25
# gender:F
# ==info of Li Weiwei==
# age:25
# gender:F
# score:15
# ID:23

# %% [markdown]
# ### Q2. 填空题：类的使用（25pts）
# 以下是一段用于活动登记的代码。其中有两个类：活动（`Activity`）和学生（`Student`）。活动有名称，主题，剩余的容量；方法上，支持扩容、输出剩余容量、列出所有参与学生的名字。学生有名字，方法有参与和退出活动，并且还有一个方法可以列出某个主题下参与的所有活动的名称。请完成填空（替换所有的`__()__`），使程序可以完成所有设计的功能。

# %%
class Activity:  
    def __init__(__(1)__, title, topic, quota):
        self.title = title  # 名称
        self.topic = topic # 主题
        self.quota = quota # 允许的学生上限
        self.participants = __(2)__  # 参与的学生列表
    def add_quota(self, __(3)__):
        self.quota += new_quota
    def print_quota(self):
        print(f'Remaining quota of activity {self.title}: {__(4)__}')
    def list_participants(self):  
        for item in self.participants:  
            print(__(5)__)
            
class Student:  
    def __init__(self, name):  
        self.name = name  # 学生名字
        self.activities = []  # 该学生参与的活动列表
    def participant(self, activity):  
        if activity in self.activities:  
            print(f'You already participate the activity - {activity.title}')  
        elif __(6)__:  
            print('There is no remaining quota for this activity.')  
        else:  
            self.activities.append(activity)  
            __(7)__
            activity.quota -= 1  
    def quit_activity(self, activity):  
        if activity __(8)__ self.activities:  
            print('You did not participate in this activity.')  
        else:  
            __(9)__
            activity.participants.remove(self)  
            __(10)__
    def list_activity_by_topic(self, topic='all'):
        print(f'==Activities of {self.name} under {topic} topic ==')
        if topic == 'all':
            tmp = self.activities
        else:
            tmp = [item for item in self.activities if __(11)__]  
            
        for item in __(12)__:  
            print(item.title)  

actv_1 = Activity('抗疫主题团日活动','疫情',50)
actv_2 = Activity('主题班会','班会',30)
actv_3 = Activity('疫情时期学习经验交流','疫情',30)

std1 = Student('Han Meimei')
std2 = Student('Ma Dongmei')

std1.participant(actv_1)
std1.participant(actv_1)
std1.participant(actv_2)
std1.participant(actv_3)
std1.list_activity_by_topic(topic='疫情')

actv_1.print_quota()
std1.quit_activity(actv_1)
actv_1.print_quota()
std1.list_activity_by_topic(topic='all')

# %%
class Activity:  
    def __init__(self, title, topic, quota):
        self.title = title  # 名称
        self.topic = topic # 主题
        self.quota = quota # 允许的学生上限
        self.participants = []  
    def add_quota(self, new_quota):
        self.quota += new_quota
    def print_quota(self):
        print(f'Remaining quota of activity {self.title}: {self.quota}')
    def list_participants(self):  
        for item in self.participants:  
            print(item.name)
            
class Student:  
    def __init__(self, name):  
        self.name = name  
        self.activities = []  
    def participant(self, activity):  
        if activity in self.activities:  
            print(f'You already participate activity - {activity.title}')  
        elif activity.quota == 0:  
            print('There is no remaining quota for this activity.')  
        else:  
            self.activities.append(activity)  
            activity.participants.append(self)
            activity.quota -= 1  
    def quit_activity(self, activity):  
        if activity not in self.activities:  
            print('You did not participate in this activity.')  
        else:  
            self.activities.remove(activity)
            activity.participants.remove(self)  
            activity.quota += 1 
    def list_activity_by_topic(self, topic='all'):
        print(f'==Activities of {self.name} under {topic} topic ==')
        if topic == 'all':
            tmp = self.activities
        else:
            tmp = [item for item in self.activities if item.topic == topic]  
            
        for item in tmp:  
            print(item.title)  

actv_1 = Activity('抗疫主题团日活动','疫情',50)
actv_2 = Activity('主题班会','班会',30)
actv_3 = Activity('疫情时期学习经验交流','疫情',30)

std1 = Student('Han Meimei')
std2 = Student('Ma Dongmei')

std1.participant(actv_1)
std1.participant(actv_1)
std1.participant(actv_2)
std1.participant(actv_3)
std1.list_activity_by_topic(topic='疫情')

actv_1.print_quota()
std1.quit_activity(actv_1)
actv_1.print_quota()
std1.list_activity_by_topic(topic='all')
# Out:
# You already participate activity - 抗疫主题团日活动
# ==Activities of Han Meimei under 疫情 topic ==
# 抗疫主题团日活动
# 疫情时期学习经验交流
# Remaining quota of activity 抗疫主题团日活动: 49
# Remaining quota of activity 抗疫主题团日活动: 50
# ==Activities of Han Meimei under all topic ==
# 主题班会
# 疫情时期学习经验交流

# %% [markdown]
# ### Q3. 类的继承（25pts）
#
# 定义三个类：三角形`Triangle`、直角三角形`RightTriangle`，等边三角形`EquilateralTriangle`
#
# * 对于三角形，初始化时候需要三个参数，分别为边`a,b,c`
# * 对于直角三角形，初始化时候需要两个参数，分别为两个直角边`a,b`
# * 对于等边三角形，初始化时候，需要一个参数，为其中一条边`a`
#
# 每个类支持的方法为初始化`__init__`、计算面积`area()`，计算周长`circum()`，是否为有效的三角形`is_valid()`。这里如果三角形无效，依然能进行初始化，但是计算周长或者面积时候，会直接输出`该三角形为无效三角形`。
#
# 合理设计三个类的继承关系，并最大限度重用代码和降低计算复杂度。如，对于直角三角形的面积应该使用`a*b`，而非以下的海伦公式。
#
# 最后测试三个类。
#
# 注意：
# * 这个题目没有最标准的答案，对于你的设计，通过注释说明其合理性即可。批改会根据总体完成度进行批改，而不是根据具体的扣分点。
# * 可以使用海伦公式：根据三角形的三边长求面积。假设三角形边长为`a,b,c`，则面积`A`为：
# $A={\sqrt  {s(s-a)(s-b)(s-c)}}$，其中${\displaystyle s={\frac {a+b+c}{2}}}$。

# %%
# your code here

# 设计说明：以Triangle作为父类，RightTriangle和EquiTriangle可以直接使用父类的circum()函数。
# 直角三角形和等边三角形的面积计算有简便方法，故而此处不使用父类的area()函数。
# is_valid()函数的话，直角三角形和等边三角形有更简单的判别方式，故而此处不使用父类的is_valid()函数。这里复杂度差别不大，所以沿用父类的话也不扣分。


class Triangle():
    def __init__(self,a,b,c):
        self.a=a
        self.b=b
        self.c=c
        
    def __str__(self): # 这个重载print可以不用进行，不扣分
        return f'==三角形，边长为{self.a}，{self.b}，{self.c}=='
    
    def is_valid(self):
        # 以下用的判别标准是两边之和大于第三边。 你也可以采用其他标准
        return self.a>0 and self.b>0 and self.c>0 and self.a+self.b>self.c and self.a+self.c>self.b and self.b+self.c>self.a
    
    def area(self):
        if self.is_valid():
            s=(self.a+self.b+self.c)/2
            A=((s*(s-self.a)*(s-self.b)*(s-self.c))**0.5)
            print(f"面积: {A}") # 也可以使用return 返回，在外部打印
        else:
            print('该三角形为无效三角形')
    
    def circum(self):
        if self.is_valid():
            print(f"周长: {self.a+self.b+self.c}") # 也可以使用return 返回，在外部打印
        else:
            print('该三角形为无效三角形')

class RightTriangle(Triangle):
    def __init__(self,a,b):
        super().__init__(a,b,c=(a**2+b**2)**0.5)
    
    def __str__(self): # 这个重载print可以不用进行，不扣分
        return f'==直角三角形，直角边为{self.a}，{self.b}'
    
    def is_valid(self):
        return self.a>0 and self.b>0 # 直角三角形 只需要两条直角边 > 0
    
    def area(self):
        if self.is_valid():
            A=0.5*self.a*self.b
            print(f"面积: {A}") # 也可以使用return 返回，在外部打印
        else:
            print('该三角形为无效三角形')
class EquilateralTriangle(Triangle):
    def __init__(self,a):
        super().__init__(a,b=a,c=a)
    
    def __str__(self): # 这个重载print可以不用进行，不扣分
        return f'==等边三角边，边长为{self.a}'
    
    def is_valid(self):
        return self.a>0 # 等边 只需要其中一条边 > 0
    
    def area(self):
        if self.is_valid():
            A=(3**0.5/4)*(self.a**2)
            print(f"面积: {A}") # 也可以使用return 返回，在外部打印
        else:
            print('该三角形为无效三角形')
        
Tri=Triangle(1,3,2)
print(Tri)
print('is_valid:', Tri.is_valid())
Tri.area()
Tri.circum()

Rig=RightTriangle(3,4)
print(Rig)
print('is_valid:', Rig.is_valid())
Rig.area()
Rig.circum()

Equ=EquilateralTriangle(3)
print(Equ)
print('is_valid:', Equ.is_valid())
Equ.area()
Equ.circum()
# Out:
# ==三角形，边长为1，3，2==
# is_valid: False
# 该三角形为无效三角形
# 该三角形为无效三角形
# ==直角三角形，直角边为3，4
# is_valid: True
# 面积: 6.0
# 周长: 12.0
# ==等边三角边，边长为3
# is_valid: True
# 面积: 3.8971143170299736
# 周长: 9

# %% [markdown]
# ### Q4.  函数编写与文件读写：censorTextFile（20pts）
# 定义一个无返回值的函数`censorTextfile(infile, outfile)`，用于英文文本文件的自动审查和敏感词替换。
#
# 该函数完成以下功能：
# - 该函数首先提示用户通过键盘输入多个需要屏蔽的英文单词，用空格分隔
# - 然后自动读入待审查文件（该文件路径通过函数参数`infile`设定）中的文本，并将该文本中出现的所有需要屏蔽的英文单词替换该单词每个字符`ASCII`码值组成的字符串（例如：假设`bbc2`是一个需要屏蔽的英文单词，则将其替换成`98989950`）
# - 将经过审查的文本（即经过上述替换处理的文本）保存到一个新文件（该文件路径通过函数参数`outfile`设定）
#
# 注意：本题可以不必考虑大小写和标点符号问题，即可以假设该文件只包含小写英文单词、空格和换行符，且文本中无标点符号。

# %%
# your code here
def censorTextfile(infile, outfile):
    # Get the list of censored words
    words_to_censor = input("Enter the censored words separated by space: ").split()

    fin = open(infile, 'r')
    fout = open(outfile, 'w')

    for line in fin:
        words = []
        for word in line.split():
            if word in words_to_censor:
                words.append(word2ascii(word))
            else:
                words.append(word)
        newLine=" ".join(words)
        print(newLine, file=fout)

    fin.close()
    fout.close()
    print("Censored file written to", outfile)

def word2ascii(word):
    newword=''
    for ch in word:
        newword=newword+str(ord(ch))+'/'
    return newword

# %% [markdown]
# ### Q5. json文件的使用（15pts）
# 课堂中我们说到`json`能以文本形式传输特定格式的数据，因此在互联网传输中也被广泛使用。例如很多网页爬虫获取的结果就是`json`格式。
#
# 以下是一个例子：京东这个产品[https://item.jd.com/497227.html](https://item.jd.com/497227.html)的第一页评论可以通过爬取这个链接获取`https://club.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98&productId=497227&score=0&sortType=5&page=0&pageSize=10&isShadowSku=0&rid=0&fold=1`，返回的结果就是`json`的文本格式，里面包含了评论相关的各种信息，例如内容，时间，用户名等。
#
# * Step 1: 执行以下两个cell，观察结果（即results这个字符串）。通过`json.loads()`将其转成字典`dic`。
#
# * Step 2: 输出每条评论的作者，时间和内容。Tips：你可以将results字符串复制到这个`json`在线预览工具[https://www.json.cn/](https://www.json.cn/)，帮助定位每条评论的位置。

# %%
# 运行第二个cell前，务必先运行这个cell，安装爬虫包 requests
# 只需要运行一次
# !pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in d:\miniconda3\lib\site-packages (2.28.1)
# Requirement already satisfied: certifi>=2017.4.17 in d:\miniconda3\lib\site-packages (from requests) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in d:\miniconda3\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\miniconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\miniconda3\lib\site-packages (from requests) (1.26.14)

# %%
import requests
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.88 Safari/537.36'}
URL = 'https://club.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98&productId=497227&score=0&sortType=5&page=1&pageSize=10&isShadowSku=0&rid=0&fold=1'
results = requests.get(URL, headers=headers).text[20:-2] #获取结果
print(results)
# Out:
# {"jwotestProduct":null,"score":0,"comments":[{"id":12288975425,"guid":"062d06c7-503f-40df-82de-4b06391e4b8f","content":"宝贝收到了，比想象中的要高端大气上档次，声音特别小，不影响休息，用上它屋里空气新鲜好多，并且还有加湿功能，特别好。","creationTime":"2018-12-21 23:12:06","isDelete":false,"isTop":false,"userImageUrl":"misc.360buyimg.com/user/myjd-2015/css/i/peisong.jpg","topped":0,"replyCount":0,"score":5,"imageStatus":1,"usefulVoteCount":0,"userClient":4,"discussionId":475213543,"imageCount":3,"anonymousFlag":1,"plusAvailable":103,"mobileVersion":"7.3.2","images":[{"id":742218592,"imgUrl":"//img30.360buyimg.com/n0/s128x96_jfs/t1/8175/5/9943/77630/5c1d02c4Ea2652f9b/ef011ed469ae2b9b.jpg","imgTitle":"","status":0},{"id":742218593,"imgUrl":"//img30.360buyimg.com/n0/s128x96_jfs/t1/14477/7/2399/100532/5c1d02c5Ea0d2083b/8c23d750b7ef3d7a.jpg","imgTitle":"","status":0},{"id":742218594,"imgUrl":"//img30.360buyimg.com/n0/s128x96_jfs/t1/27429/20/2455/83860/5c1d02c5Ef81500f8/02c8beff0fe54c54.jpg","imgTitle":"","status":0}],"mergeOrderStatus":2,"productColor":"变形金刚限量版VXG70","productSize":"","textIntegral":40,"imageIntegral":20,"extMap":{"buyCount":1},"status":1,"referenceId":"100002123454","referenceTime":"2018-12-20 00:03:11","nickname":"j***n","replyCount2":0,"userImage":"misc.360buyimg.com/user/myjd-2015/css/i/peisong.jpg","orderId":0,"integral":60,"productSales":"[]","referenceImage":"jfs/t1/149073/10/40144/74928/64f1aaefF7f992d37/44e3a8f7a7a7a17e.jpg","referenceName":"松下（Panasonic） VXG70C空气净化器 纳诺怡除菌除异味除过敏原 加湿一体 50平米","firstCategory":737,"secondCategory":738,"thirdCategory":749,"aesPin":null,"days":1,"afterDays":0},{"id":12346274452,"guid":"0bbad8f0-5392-44c7-a517-96aea17d73b6","content":"以前买过松下的一款PXJ30空气净化器，这次家里添家具，又买了一台，收到宝贝的时候打开试了试，和以前的那台比，功能真是高大上，除了净化空气，还有除尘、加湿各种功能，以后房间里开空调不用再放盆水了，一分钱一分货，总之超级赞!","creationTime":"2019-01-07 11:02:06","isDelete":false,"isTop":false,"userImageUrl":"storage.360buyimg.com/i.imageUpload/31353138393733333432365f7031363131383336363935303935_sma.jpg","topped":0,"replyCount":0,"score":5,"imageStatus":1,"usefulVoteCount":1,"userClient":2,"discussionId":483106630,"imageCount":5,"anonymousFlag":1,"plusAvailable":201,"mobileVersion":"7.2.2","images":[{"id":754308454,"imgUrl":"//img30.360buyimg.com/n0/s128x96_jfs/t1/18018/2/4501/112152/5c32c129E7daa87fb/1d3700bfdeddc1e1.jpg","imgTitle":"","status":0},{"id":754308455,"imgUrl":"//img30.360buyimg.com/n0/s128x96_jfs/t1/16837/33/4433/115976/5c32c12dEad920afb/f0bb0298c6f861d4.jpg","imgTitle":"","status":0},{"id":754308456,"imgUrl":"//img30.360buyimg.com/n0/s128x96_jfs/t1/17560/11/4512/138206/5c32c12eEd1004807/45f3fc57267ec4c1.jpg","imgTitle":"","status":0},{"id":754308457,"imgUrl":"//img30.360buyimg.com/n0/s128x96_jfs/t1/19123/19/4546/106244/5c32c12dE36d61fdb/e0a0c4f516b41c2d.jpg","imgTitle":"","status":0},{"id":754308458,"imgUrl":"//img30.360buyimg.com/n0/s128x96_jfs/t1/20867/1/4491/59648/5c32c12dE803b6935/9ede020eed835400.jpg","imgTitle":"","status":0}],"mergeOrderStatus":2,"productColor":"变形金刚限量版VXG70","productSize":"","textIntegral":20,"imageIntegral":20,"extMap":{"buyCount":1},"status":1,"referenceId":"100002123454","referenceTime":"2019-01-04 10:06:19","nickname":"丸***号","replyCount2":0,"userImage":"storage.360buyimg.com/i.imageUpload/31353138393733333432365f7031363131383336363935303935_sma.jpg","orderId":0,"integral":40,"productSales":"[]","referenceImage":"jfs/t1/149073/10/40144/74928/64f1aaefF7f992d37/44e3a8f7a7a7a17e.jpg","referenceName":"松下（Panasonic） VXG70C空气净化器 纳诺怡除菌除异味除过敏原 加湿一体 50平米","firstCategory":737,"secondCategory":738,"thirdCategory":749,"aesPin":null,"days":3,"afterDays":0},{"id":12456549244,"guid":"68a9f687-9787-4ffa-a0f0-3ee32c9e7d8d","content":"小日本的东西设计确实可以，使用很方便，加湿也快，净化器感应特别灵敏","creationTime":"2019-02-16 06:44:04","isDelete":false,"isTop":false,"userImageUrl":"storage.360buyimg.com/i.imageUpload/73756e6e79713032313931353530393733373535303435_sma.jpg","topped":0,"replyCount":0,"score":5,"imageStatus":1,"usefulVoteCount":0,"userClient":2,"discussionId":499841063,"imageCount":3,"anonymousFlag":1,"plusAva ...

# %%
#your code here
# 通过借助在线预览工具https://www.json.cn/，发现评论数据都在这个字典的 ‘comments’字段。
# 取每条评论，又是另一个字典，里边包含各种信息，包括题目要求的：评论的作者，时间和内容
import json
data=json.loads(results)
for i, item in enumerate(data['comments']):
    print(f'========={i+1}-th record========')
    print('作者ID: %d'%item['id'])
    print('时间: %s'%item['creationTime'])
    print('内容: %s'%item['content'])
# Out:
# =========1-th record========
# 作者ID: 12288975425
# 时间: 2018-12-21 23:12:06
# 内容: 宝贝收到了，比想象中的要高端大气上档次，声音特别小，不影响休息，用上它屋里空气新鲜好多，并且还有加湿功能，特别好。
# =========2-th record========
# 作者ID: 12346274452
# 时间: 2019-01-07 11:02:06
# 内容: 以前买过松下的一款PXJ30空气净化器，这次家里添家具，又买了一台，收到宝贝的时候打开试了试，和以前的那台比，功能真是高大上，除了净化空气，还有除尘、加湿各种功能，以后房间里开空调不用再放盆水了，一分钱一分货，总之超级赞!
# =========3-th record========
# 作者ID: 12456549244
# 时间: 2019-02-16 06:44:04
# 内容: 小日本的东西设计确实可以，使用很方便，加湿也快，净化器感应特别灵敏
# =========4-th record========
# 作者ID: 12350182739
# 时间: 2019-01-08 12:25:57
# 内容: 东北室内地热干燥，又不能总开窗。选了好久，选中了这款。到货立刻插上用了，全是红灯的预警，连续运转，希望能尽快改变室内空气质量。外观大气，很有质感，不算占地方。期待带来的改变。用过之后再来评价使用体验！
# =========5-th record========
# 作者ID: 12311706101
# 时间: 2018-12-28 11:00:20
# 内容: 包装很完整，配件齐全。样式好看，检测灵敏，在抽烟就红了，然后盖子自动打开，赞。自带加湿，特别适合开空调的时候。
# =========6-th record========
# 作者ID: 12286389735
# 时间: 2018-12-21 11:03:00
# 内容: 快递很给力，加湿器不错，符合预期效果，操作简单，外观很棒。已经开通，雾霾害***😊
# =========7-th record========
# 作者ID: 12302793705
# 时间: 2018-12-25 20:08:05
# 内容: 机子很棒，净化效果很明显，每次看着从大红转到蓝色状态，总觉得很放心，会推荐朋友使用
# =========8-th record========
# 作者ID: 12284096208
# 时间: 2018-12-20 17:39:29
# 内容: 京东快递速度是真的快，零点抢购的，当天下午就收到了。机器收到就开箱使用，安静，清洁迅速。感觉非常的满意。新人松下，信任京东。
# =========9-th record========
# 作者ID: 12308729809
# 时间: 2018-12-27 13:51:29
# 内容: 非常好，质量很棒，超预期了这个，效果非常明显，北京空气太干，这个正好用，之前宝宝老是咳嗽，现在都不咳嗽了，你说神不神奇，感谢。
# =========10-th record========
# 作者ID: 12317537105
# 时间: 2018-12-29 22:55:50
# 内容: 朋友推荐的，果然很不错，晚上暖气房里就不觉得口干舌燥了，睡眠模式也很静音，完胜普通加湿器

# %% [markdown]
# ### Q-Bonus. 函数编写与数据结构的使用：判断括号使用是否合法（10pts，允许最终总分高于100分，但是4次作业总分上限不能高于400分）
# Step 1: 编写函数`is_valid_parenthese_str(str1)`, 该函数接受一个字符串参数`str1`, 假设该字符串只包含括号（即 `(`, `)`, `{`, `}`, `[`, `]` ）。函数需要判断这些括号是否按正确的顺序闭合。举例：`()`和`()[]{}`和`[()]`是合法的，而 `[)`, `({[)]`和 `{{{`是不合法的
#
# Step 2: 用以下几个字符串测试你的函数：
#   * `[{}([])] -> True`
#   * `(){}[] -> True`
#   * `()[{)} -> False`
#
# 提示：想象你在进行一个消消乐游戏，从左往右，碰到左括号就保存到一个待消除左括号列表里，碰到右括号就和最近的左括号消除。如果最后待消除左括号列表为空，那么括号合法。以下已经给出了函数的框架，你只需要补充完整即可。如果你的思路不一样，也可以重新写一个函数。

# %%
# your codes here
def is_valid_parenthese_str(str1):
    '''
    判断输入的字符串是否是有效的括号字符串
    '''
    recent_left_parenthese = []
    pmap = {"(": ")", 
            "{": "}", 
            "[": "]"}
    for parenthese in str1:
        if parenthese in pmap: # 碰到新的左括号
            
        else: # 碰到右括号
            
    return 

print(is_valid_parenthese_str("[{}([])]"))
print(is_valid_parenthese_str("(){}[]"))
print(is_valid_parenthese_str("()[{)}"))

# %%
# your codes here
def is_valid_parenthese_str(str1):
    '''
    判断输入的字符串是否是有效的括号字符串
    '''
    recent_left_parenthese = []
    pmap = {"(": ")", 
            "{": "}", 
            "[": "]"}
    for parenthese in str1:
        if parenthese in pmap: # 碰到新的左括号
            recent_left_parenthese.append(parenthese)
        else: # 碰到右括号
            if len(recent_left_parenthese) == 0:
                return False # 如果左边没有左括号
            most_recent_left_parenthese = recent_left_parenthese.pop() # 删除最后一个元素并返回该元素
            if pmap[most_recent_left_parenthese] != parenthese:
                return False
    return len(recent_left_parenthese) == 0  # 第一个左括号必须有合适的右括号

print(is_valid_parenthese_str("[{}([])]"))
print(is_valid_parenthese_str("(){}[]"))
print(is_valid_parenthese_str("()[{)}"))
